# %%
import numpy as np
import pandas as pd
import csv

# %%
df = pd.read_csv("employment/employment_data_by_county.csv")
df.head()
# Out:
#            GEO_ID                     NAME  \
# 0              id     Geographic Area Name
# 1  0500000US01001  Autauga County, Alabama
# 2  0500000US01003  Baldwin County, Alabama
# 3  0500000US01005  Barbour County, Alabama
# 4  0500000US01007     Bibb County, Alabama
#
#                                       S2405_C02_007E  \
# 0  Estimate!!Management, business, science, and a...
# 1                                               16.7
# 2                                                 19
# 3                                               15.8
# 4                                                2.5
#
#                                       S2405_C02_007M  \
# 0  Margin of Error!!Management, business, science...
# 1                                                7.1
# 2                                                4.3
# 3                                                9.7
# 4                                                2.7
#
# ...

# %%
legend_df = pd.read_csv("employment/employment_legend.csv")
legend_df
# Out:
#              GEO_ID                                                 id  \
# 0              NAME                               Geographic Area Name
# 1    S2405_C01_001E  Estimate!!Total!!Civilian employed population ...
# 2    S2405_C01_001M  Margin of Error!!Total MOE!!Civilian employed ...
# 3    S2405_C01_002E  Estimate!!Total!!Civilian employed population ...
# 4    S2405_C01_002M  Margin of Error!!Total MOE!!Civilian employed ...
# ..              ...                                                ...
# 176  S2405_C06_013M  Margin of Error!!Production, transportation, a...
# 177  S2405_C06_014E  Estimate!!Production, transportation, and mate...
# 178  S2405_C06_014M  Margin of Error!!Production, transportation, a...
# 179  S2405_C06_015E  Estimate!!Production, transportation, and mate...
# 180  S2405_C06_015M  Margin of Error!!Production, transportation, a...
#
#      Unnamed: 2
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...

# %%
df_estimate = df.loc[:, ~df.columns.str.endswith('M')]
df_estimate.head()
# Out:
#            GEO_ID                     NAME  \
# 0              id     Geographic Area Name
# 1  0500000US01001  Autauga County, Alabama
# 2  0500000US01003  Baldwin County, Alabama
# 3  0500000US01005  Barbour County, Alabama
# 4  0500000US01007     Bibb County, Alabama
#
#                                       S2405_C02_007E  \
# 0  Estimate!!Management, business, science, and a...
# 1                                               16.7
# 2                                                 19
# 3                                               15.8
# 4                                                2.5
#
#                                       S2405_C03_007E  \
# 0  Estimate!!Service occupations!!Civilian employ...
# 1                                                0.4
# 2                                                  3
# 3                                                1.3
# 4                                                8.8
#
# ...

# %%
df_sector = df_estimate.loc[:, df_estimate.columns.str.contains("C01")]
df_sector.head()
# Out:
#                                       S2405_C01_008E  \
# 0  Estimate!!Total!!Civilian employed population ...
# 1                                                393
# 2                                               1279
# 3                                                 21
# 4                                                106
#
#                                       S2405_C01_009E  \
# 0  Estimate!!Total!!Civilian employed population ...
# 1                                               1510
# 2                                               6909
# 3                                                346
# 4                                                371
#
#                                       S2405_C01_010E  \
# 0  Estimate!!Total!!Civilian employed population ...
# 1                                               2158
# 2                                               9940
# 3                                                416
# ...

# %%
df_sector.shape
# Out:
# (3221, 15)

# %%
sector_name = legend_df[legend_df["GEO_ID"].str.contains("C01")]
sector_name
# Out:
#             GEO_ID                                                 id  \
# 1   S2405_C01_001E  Estimate!!Total!!Civilian employed population ...
# 2   S2405_C01_001M  Margin of Error!!Total MOE!!Civilian employed ...
# 3   S2405_C01_002E  Estimate!!Total!!Civilian employed population ...
# 4   S2405_C01_002M  Margin of Error!!Total MOE!!Civilian employed ...
# 5   S2405_C01_003E  Estimate!!Total!!Civilian employed population ...
# 6   S2405_C01_003M  Margin of Error!!Total MOE!!Civilian employed ...
# 7   S2405_C01_004E  Estimate!!Total!!Civilian employed population ...
# 8   S2405_C01_004M  Margin of Error!!Total MOE!!Civilian employed ...
# 9   S2405_C01_005E  Estimate!!Total!!Civilian employed population ...
# 10  S2405_C01_005M  Margin of Error!!Total MOE!!Civilian employed ...
# 11  S2405_C01_006E  Estimate!!Total!!Civilian employed population ...
# 12  S2405_C01_006M  Margin of Error!!Total MOE!!Civilian employed ...
# ...

# %%
sector_name = sector_name[sector_name["GEO_ID"].str.endswith("E")]
sector_name
# Out:
#             GEO_ID                                                 id  \
# 1   S2405_C01_001E  Estimate!!Total!!Civilian employed population ...
# 3   S2405_C01_002E  Estimate!!Total!!Civilian employed population ...
# 5   S2405_C01_003E  Estimate!!Total!!Civilian employed population ...
# 7   S2405_C01_004E  Estimate!!Total!!Civilian employed population ...
# 9   S2405_C01_005E  Estimate!!Total!!Civilian employed population ...
# 11  S2405_C01_006E  Estimate!!Total!!Civilian employed population ...
# 13  S2405_C01_007E  Estimate!!Total!!Civilian employed population ...
# 15  S2405_C01_008E  Estimate!!Total!!Civilian employed population ...
# 17  S2405_C01_009E  Estimate!!Total!!Civilian employed population ...
# 19  S2405_C01_010E  Estimate!!Total!!Civilian employed population ...
# 21  S2405_C01_011E  Estimate!!Total!!Civilian employed population ...
# 23  S2405_C01_012E  Estimate!!Total!!Civilian employed population ...
# ...

# %%
sector_name.shape
# Out:
# (15, 3)

# %%
sector_name_series = sector_name["id"].to_list()
sector_name_series
# Out:
# ['Estimate!!Total!!Civilian employed population 16 years and over',
#  'Estimate!!Total!!Civilian employed population 16 years and over!!Agriculture, forestry, fishing and hunting, and mining',
#  'Estimate!!Total!!Civilian employed population 16 years and over!!Construction',
#  'Estimate!!Total!!Civilian employed population 16 years and over!!Manufacturing',
#  'Estimate!!Total!!Civilian employed population 16 years and over!!Wholesale trade',
#  'Estimate!!Total!!Civilian employed population 16 years and over!!Retail trade',
#  'Estimate!!Total!!Civilian employed population 16 years and over!!Transportation and warehousing, and utilities',
#  'Estimate!!Total!!Civilian employed population 16 years and over!!Information',
#  'Estimate!!Total!!Civilian employed population 16 years and over!!Finance and insurance, and real estate and rental and leasing',
# ...

# %%
df_sector = df_sector.drop(["S2405_C01_001E", "S2405_C01_015E"],1)
df_sector.head()
# Out:
#                                       S2405_C01_008E  \
# 0  Estimate!!Total!!Civilian employed population ...
# 1                                                393
# 2                                               1279
# 3                                                 21
# 4                                                106
#
#                                       S2405_C01_009E  \
# 0  Estimate!!Total!!Civilian employed population ...
# 1                                               1510
# 2                                               6909
# 3                                                346
# 4                                                371
#
#                                       S2405_C01_010E  \
# 0  Estimate!!Total!!Civilian employed population ...
# 1                                               2158
# 2                                               9940
# 3                                                416
# ...

# %%
df_sector = df_sector.drop(df_sector.index[0])
df_sector.head()
# Out:
#   S2405_C01_008E S2405_C01_009E S2405_C01_010E S2405_C01_011E S2405_C01_012E  \
# 1            393           1510           2158           4844           1960
# 2           1279           6909           9940          18758           9416
# 3             21            346            416           1626            516
# 4            106            371            380           1847            356
# 5            267           1246           1639           4204            987
#
#   S2405_C01_013E S2405_C01_014E S2405_C01_002E S2405_C01_003E S2405_C01_004E  \
# 1           1507           2473            213           1448           3123
# 2           4581           4731           1240           7722           8516
# 3            382            619            394            545           2083
# 4            606            427            485            730           1515
# 5           1271            979            487           2020           3503
#
# ...

# %%
sector_name['id'] = sector_name['id'].map(lambda x: x.lstrip('Estimate!!Total!!Civilian employed population 16 years and over!!'))
sector_name
# Out:
# /Users/pegkhiev/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#             GEO_ID                                                 id  \
# 1   S2405_C01_001E
# 3   S2405_C01_002E  Agriculture, forestry, fishing and hunting, an...
# 5   S2405_C01_003E                                              ction
# 7   S2405_C01_004E                                      Manufacturing
# 9   S2405_C01_005E                                    Wholesale trade
# 11  S2405_C01_006E                                       Retail trade
# 13  S2405_C01_007E                         warehousing, and utilities
# ...

# %%
sector_name = sector_name.drop([sector_name.index[0], sector_name.index[14]])
sector_name = sector_name.replace("ction", "Construction")
sector_name
# Out:
#             GEO_ID                                                 id  \
# 3   S2405_C01_002E  Agriculture, forestry, fishing and hunting, an...
# 5   S2405_C01_003E                                       Construction
# 7   S2405_C01_004E                                      Manufacturing
# 9   S2405_C01_005E                                    Wholesale trade
# 11  S2405_C01_006E                                       Retail trade
# 13  S2405_C01_007E                         warehousing, and utilities
# 15  S2405_C01_008E                                        Information
# 17  S2405_C01_009E  Finance and insurance, and real estate and ren...
# 19  S2405_C01_010E  Professional, scientific, and management, and ...
# 21  S2405_C01_011E  cational services, and health care and social ...
# 23  S2405_C01_012E  Arts, entertainment, and recreation, and accom...
# 25  S2405_C01_013E       Other services, except public administration
# ...

# %%
ID_sequence = sector_name["GEO_ID"]
ID_sequence
# Out:
# 3     S2405_C01_002E
# 5     S2405_C01_003E
# 7     S2405_C01_004E
# 9     S2405_C01_005E
# 11    S2405_C01_006E
# 13    S2405_C01_007E
# 15    S2405_C01_008E
# 17    S2405_C01_009E
# 19    S2405_C01_010E
# 21    S2405_C01_011E
# 23    S2405_C01_012E
# 25    S2405_C01_013E
# 27    S2405_C01_014E
# Name: GEO_ID, dtype: object

# %%
df_sector = df_sector[ID_sequence]
df_sector.head()
# Out:
#   S2405_C01_002E S2405_C01_003E S2405_C01_004E S2405_C01_005E S2405_C01_006E  \
# 1            213           1448           3123            656           2154
# 2           1240           7722           8516           2887          12801
# 3            394            545           2083            243            926
# 4            485            730           1515            139            741
# 5            487           2020           3503            768           2510
#
#   S2405_C01_007E S2405_C01_008E S2405_C01_009E S2405_C01_010E S2405_C01_011E  \
# 1           1685            393           1510           2158           4844
# 2           4599           1279           6909           9940          18758
# 3            603             21            346            416           1626
# 4            396            106            371            380           1847
# 5           1465            267           1246           1639           4204
#
# ...

# %%
sectors = sector_name["id"]

# %%
df_sector.columns = sectors
df_sector.head()
# Out:
# id Agriculture, forestry, fishing and hunting, and mining Construction  \
# 1                                                 213             1448
# 2                                                1240             7722
# 3                                                 394              545
# 4                                                 485              730
# 5                                                 487             2020
#
# id Manufacturing Wholesale trade Retail trade warehousing, and utilities  \
# 1           3123             656         2154                       1685
# 2           8516            2887        12801                       4599
# 3           2083             243          926                        603
# 4           1515             139          741                        396
# 5           3503             768         2510                       1465
#
# id Information Finance and insurance, and real estate and rental and leasing  \
# ...

# %%
max_sector = df_sector.max(axis = 1)
max_sector
# Out:
# 1        656.0
# 2       9940.0
# 3        926.0
# 4        741.0
# 5        987.0
#          ...
# 3216     981.0
# 3217      98.0
# 3218     768.0
# 3219      82.0
# 3220      99.0
# Length: 3220, dtype: float64

# %%
df_sector.dtypes
# Out:
# id
# Agriculture, forestry, fishing and hunting, and mining                                        object
# Construction                                                                                  object
# Manufacturing                                                                                 object
# Wholesale trade                                                                               object
# Retail trade                                                                                  object
# warehousing, and utilities                                                                    object
# Information                                                                                   object
# Finance and insurance, and real estate and rental and leasing                                 object
# Professional, scientific, and management, and administrative and waste management services    object
# ...

# %%
df_sector = df_sector.apply(pd.to_numeric) 
df_sector.dtypes
# Out:
# id
# Agriculture, forestry, fishing and hunting, and mining                                        float64
# Construction                                                                                  float64
# Manufacturing                                                                                 float64
# Wholesale trade                                                                               float64
# Retail trade                                                                                  float64
# warehousing, and utilities                                                                    float64
# Information                                                                                   float64
# Finance and insurance, and real estate and rental and leasing                                 float64
# Professional, scientific, and management, and administrative and waste management services    float64
# ...

# %%
max_sector = df_sector.max(axis = 1)
max_sector
# Out:
# 1        4844.0
# 2       18758.0
# 3        2083.0
# 4        1847.0
# 5        4204.0
#          ...
# 3216     3694.0
# 3217      536.0
# 3218     1531.0
# 3219     2083.0
# 3220     2632.0
# Length: 3220, dtype: float64

# %%
df_sector["Largest_Sector"] = max_sector
df_sector.head()
# Out:
# id  Agriculture, forestry, fishing and hunting, and mining  Construction  \
# 1                                               213.0             1448.0
# 2                                              1240.0             7722.0
# 3                                               394.0              545.0
# 4                                               485.0              730.0
# 5                                               487.0             2020.0
#
# id  Manufacturing  Wholesale trade  Retail trade  warehousing, and utilities  \
# 1          3123.0            656.0        2154.0                      1685.0
# 2          8516.0           2887.0       12801.0                      4599.0
# 3          2083.0            243.0         926.0                       603.0
# 4          1515.0            139.0         741.0                       396.0
# 5          3503.0            768.0        2510.0                      1465.0
#
# id  Information  \
# 1         393.0
# 2        1279.0
# ...

# %%
df_largest_sector = df_sector.filter(["Largest_Sector"], axis = 1)
df_largest_sector.head()
# Out:
# id  Largest_Sector
# 1           4844.0
# 2          18758.0
# 3           2083.0
# 4           1847.0
# 5           4204.0

# %%
df_largest_sector.shape
# Out:
# (3220, 1)

# %%
df_largest_sector = df_sector.idxmax(axis=1)
df_largest_sector.head()
# Out:
# 1    cational services, and health care and social ...
# 2    cational services, and health care and social ...
# 3                                        Manufacturing
# 4    cational services, and health care and social ...
# 5    cational services, and health care and social ...
# dtype: object

# %%
df_sector["Largest_sector"] = df_largest_sector
df_sector.head()
# Out:
# id  Agriculture, forestry, fishing and hunting, and mining  Construction  \
# 1                                               213.0             1448.0
# 2                                              1240.0             7722.0
# 3                                               394.0              545.0
# 4                                               485.0              730.0
# 5                                               487.0             2020.0
#
# id  Manufacturing  Wholesale trade  Retail trade  warehousing, and utilities  \
# 1          3123.0            656.0        2154.0                      1685.0
# 2          8516.0           2887.0       12801.0                      4599.0
# 3          2083.0            243.0         926.0                       603.0
# 4          1515.0            139.0         741.0                       396.0
# 5          3503.0            768.0        2510.0                      1465.0
#
# id  Information  \
# 1         393.0
# 2        1279.0
# ...

# %%
df_sector = df_sector.replace("cational services, and health care and social assistance",
                              "Educational services, and health care and social assistance")
df_sector.head()
# Out:
# id  Agriculture, forestry, fishing and hunting, and mining  Construction  \
# 1                                               213.0             1448.0
# 2                                              1240.0             7722.0
# 3                                               394.0              545.0
# 4                                               485.0              730.0
# 5                                               487.0             2020.0
#
# id  Manufacturing  Wholesale trade  Retail trade  warehousing, and utilities  \
# 1          3123.0            656.0        2154.0                      1685.0
# 2          8516.0           2887.0       12801.0                      4599.0
# 3          2083.0            243.0         926.0                       603.0
# 4          1515.0            139.0         741.0                       396.0
# 5          3503.0            768.0        2510.0                      1465.0
#
# id  Information  \
# 1         393.0
# 2        1279.0
# ...

# %%
df_sector = df_sector.replace("warehousing, and utilities",
                              "Transportation and warehousing, and utilities")
df_sector.head()
# Out:
# id  Agriculture, forestry, fishing and hunting, and mining  Construction  \
# 1                                               213.0             1448.0
# 2                                              1240.0             7722.0
# 3                                               394.0              545.0
# 4                                               485.0              730.0
# 5                                               487.0             2020.0
#
# id  Manufacturing  Wholesale trade  Retail trade  warehousing, and utilities  \
# 1          3123.0            656.0        2154.0                      1685.0
# 2          8516.0           2887.0       12801.0                      4599.0
# 3          2083.0            243.0         926.0                       603.0
# 4          1515.0            139.0         741.0                       396.0
# 5          3503.0            768.0        2510.0                      1465.0
#
# id  Information  \
# 1         393.0
# 2        1279.0
# ...

# %%
df_clean_sector = df_sector.filter(["Largest_sector"], axis = 1)
df_clean_sector.head()
# Out:
# id                                     Largest_sector
# 1   Educational services, and health care and soci...
# 2   Educational services, and health care and soci...
# 3                                       Manufacturing
# 4   Educational services, and health care and soci...
# 5   Educational services, and health care and soci...

# %%
df_clean_sector.to_csv('largest_sector_by_county.csv')

# %%
df_sector.loc[1810:1820]
# Out:
# id    Agriculture, forestry, fishing and hunting, and mining  Construction  \
# 1810                                              325.0              686.0
# 1811                                               42.0              137.0
# 1812                                              764.0              592.0
# 1813                                              614.0             1119.0
# 1814                                               93.0              110.0
# 1815                                              597.0             1947.0
# 1816                                              127.0              190.0
# 1817                                                NaN                NaN
# 1818                                              819.0              498.0
# 1819                                              774.0             4522.0
# 1820                                             6184.0             3761.0
#
# id    Manufacturing  Wholesale trade  Retail trade  \
# ...
